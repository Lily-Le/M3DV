# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
tmp = np.load('E:/大学学习/作业&presentation/ML/大作业/sjtu-ee228-2020/test/test/candidate11.npz')

# %%
tmp['voxel']
# Out:
# array([[[ 38,  43,  33, ..., 192, 189, 188],
#         [ 47,  41,  43, ..., 188, 184, 183],
#         [ 47,  65,  55, ..., 183, 192, 186],
#         ...,
#         [187, 188, 179, ...,  17,  23,  17],
#         [190, 186, 184, ...,  27,  20,  20],
#         [182, 185, 174, ...,  14,  20,  24]],
#
#        [[ 38,  39,  33, ..., 189, 194, 194],
#         [ 56,  42,  46, ..., 185, 194, 186],
#         [ 44,  67,  73, ..., 179, 192, 193],
#         ...,
#         [186, 189, 191, ...,  21,  13,  14],
#         [193, 190, 171, ...,  15,  18,  22],
#         [200, 180, 177, ...,  15,  11,  11]],
#
#        [[ 33,  45,  32, ..., 186, 191, 195],
#         [ 49,  41,  36, ..., 192, 193, 193],
#         [ 43,  55,  65, ..., 191, 183, 193],
#         ...,
#         [191, 191, 187, ...,  12,  19,  21],
#         [192, 191, 180, ...,  10,  16,  17],
#         [199, 189, 172, ...,  21,  11,   9]],
#
#        ...,
#
#        [[  3,   9,   1, ...,   7,   4,  11],
# ...

# %%
tmp['seg']
# Out:
# array([[[False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False],
#         ...,
#         [False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False]],
#
#        [[False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False],
#         ...,
#         [False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False]],
#
#        [[False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False],
#         ...,
#         [False, False, False, ..., False, False, False],
# ...

# %%
np.shape(tmp['voxel'])
# Out:
# (100, 100, 100)

# %%
np.shape(tmp['seg'])
# Out:
# (100, 100, 100)

# %%
voxel = tmp['voxel']/255
seg = tmp['seg']

# %%
for i in range(37,60,2):
    plt.figure()
    plt.subplot(1,2,1)
    plt.imshow(seg[i])
    plt.subplot(1,2,2)
    plt.imshow(voxel[i])
    plt.show()
